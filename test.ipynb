# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cities = gpd.read_file(gpd.datasets.get_path(gpd.datasets.available[0]))

# %%
cities.plot()

# %%
from geoplot import core

# %%
core._initialize_folium_layer(cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import pandas as pd

# %%
core.point(cities['geometry'].sample(2))
# Out:
# (17.11698075223461, 33.8739209756269, 35.507762351377664, 48.15001832996171)
# None
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'])
# Out:
# (-175.22056447761656, -41.29997393927641, 179.21664709402887, 64.15002361973922)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
collisions = pd.read_csv("NYPD Motor Vehicle Collisions.csv")

# %%
import folium

# %%
folium.map.FitBounds?

# %%
webmap = folium.Map()
pass

# %%
webmap.fit_bounds?

# %%
folium.Map()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c67db2a66195> in <module>()
# ----> 1 folium.Map().FitBounds
#
# AttributeError: 'Map' object has no attribute 'FitBounds'
