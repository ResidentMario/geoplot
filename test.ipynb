# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
cities = gpd.read_file(gpd.datasets.get_path(gpd.datasets.available[0]))

# %%
cities.plot()

# %%
import pandas as pd

# %%
pd.DataFrame(cities).plot

# %%
cities.plot?

# %%
from geoplot import core

# %%
import pandas as pd

# %%
folium.folium.Map?

# %%
folium.Map?

# %%
folium.folium.LegacyMap?

# %%
cities['geometry'][[0, 1]]
# Out:
# 0    POINT (12.45338654497177 41.90328217996012)
# 1      POINT (12.44177015780014 43.936095834768)
# Name: geometry, dtype: object

# %%
core.point(cities.sample(5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'][[0, 1]])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'][[0, 1]])
# Out:
# (12.441770157800141, 41.903282179960115, 12.453386544971766, 43.936095834768004)
# (12.447578351385953, 42.919689007364056)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import pandas as pd

# %%
gpd.GeoSeries(pd.Series({1: (0, 0), 2: (1, 2)}))
# Out:
# 1    (0, 0)
# 2    (1, 2)
# dtype: object

# %%
gpd.GeoSeries(pd.Series({1: (0, 0), 2: (1, 2)}))[1]
# Out:
# (0, 0)

# %%
core.point(cities, padding=100)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'][[0, 1]], padding=100)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'].sample(2))
# Out:
# (15.047202455462298, -25.704974695184433, 28.22748321723384, 12.115042394810644)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
core.point(cities['geometry'])
# Out:
# (-175.22056447761656, -41.29997393927641, 179.21664709402887, 64.15002361973922)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
collisions = pd.read_csv("NYPD Motor Vehicle Collisions.csv")

# %%
import folium

# %%
folium.map.FitBounds?

# %%
webmap = folium.Map()
pass

# %%
webmap.fit_bounds?

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
