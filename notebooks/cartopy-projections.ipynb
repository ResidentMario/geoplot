# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import matplotlib.pyplot as plt
# import sys; sys.path.insert(0, '../')
# import geoplot.crs as ccrs
# import geoplot as gplt
import cartopy.crs as ccrs
import cartopy
# %matplotlib inline

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()

ax.scatter([0, 15, 30, 45, 60, 75, 90], [0, 15, 30, 45, 60, 75, 90], transform=ccrs.PlateCarree())

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree(central_longitude=-45))
ax.set_global()
ax.coastlines()

ax.scatter([0, 15, 30, 45, 60, 75, 90], [0, 15, 30, 45, 60, 75, 90], transform=ccrs.PlateCarree())

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree(central_longitude=-45))
ax.set_global()
ax.coastlines()

ax.scatter([0, 15, 30, 45, 60, 75, 90], [0, 15, 30, 45, 60, 75, 90], transform=ccrs.PlateCarree(central_longitude=-45))

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()

ax.scatter([-98.583333], [39.833333], transform=ccrs.PlateCarree())

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree(central_longitude=-98.583333))
ax.set_global()
ax.coastlines()

ax.scatter([-98.583333], [39.833333], transform=ccrs.PlateCarree())

# %%
ax = plt.subplot(111, projection=ccrs.PlateCarree(central_longitude=-98.583333))
ax.set_extent((-90.0, 180.0, -90.0, 90.0))
ax.coastlines()

ax.scatter([-98.583333], [39.833333], transform=ccrs.PlateCarree())

# %%
ax = plt.subplot(111, projection=ccrs.AlbersEqualArea(central_longitude=-98.583333))
ax.set_extent((-90.0, 180.0, -90.0, 90.0))
ax.coastlines()

ax.scatter([-98.583333], [39.833333], transform=ccrs.PlateCarree())

# %%
data = gpd.GeoDataFrame(geometry=[Point(0, 0)])
xs = [g.x for g in data.geometry]
ys = [g.y for g in data.geometry]
