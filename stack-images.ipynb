# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geoplot import utils
import geoplot as gplt
from geoplot import crs as ccrs
import geopandas as gpd
import pandas as pd
import shapely
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter([1,2],[1,2])
plt.scatter([3,4],[3,4])

# %%
points_1 = utils.gaussian_points()
points_2 = utils.gaussian_points()

gplt.pointplot(points_1, projection=ccrs.PlateCarree())
ax = plt.gca()
gplt.pointplot(points_2, projection=ccrs.PlateCarree(), ax=ax)

# %%
points_1 = utils.gaussian_points()
points_2 = utils.gaussian_points()

ax = gplt.pointplot(points_1, projection=ccrs.PlateCarree())
gplt.pointplot(points_2, projection=ccrs.PlateCarree(), ax=ax)
