# %%
import geopandas as gpd

def exec():
    import pdb; pdb.set_trace()
    census_tracts = gpd.read_file("./data/nyc_census_tracts_2010.geojson", driver='GeoJSON')

# %%
exec()
# Out:
# > <ipython-input-1-25c7056ae5af>(5)exec()
# -> census_tracts = gpd.read_file("./data/nyc_census_tracts_2010.geojson", driver='GeoJSON')
# (Pdb) s
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\geopandas\io\file.py(11)read_file()
# -> def read_file(filename, **kwargs):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\geopandas\io\file.py(20)read_file()
# -> bbox = kwargs.pop('bbox', None)
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\geopandas\io\file.py(21)read_file()
# -> with fiona.open(filename, **kwargs) as f:
# (Pdb) s
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(101)open()
# -> def open(
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(167)open()
# -> path, vsi, archive = parse_paths(path, vfs)
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(168)open()
# -> if mode in ('a', 'r'):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(169)open()
# -> if archive:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(172)open()
# -> elif path != '-' and not os.path.exists(path):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(174)open()
# -> c = Collection(path, mode, driver=driver, encoding=encoding,
# (Pdb) s
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(175)open()
# -> layer=layer, vsi=vsi, archive=archive,
# (Pdb) s
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\__init__.py(176)open()
# -> enabled_drivers=enabled_drivers)
# (Pdb) s
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(26)__init__()
# -> def __init__(self, path, mode='r', driver=None, schema=None, crs=None,
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(45)__init__()
# -> if not isinstance(path, string_types):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(47)__init__()
# -> if not isinstance(mode, string_types) or mode not in ('r', 'w', 'a'):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(49)__init__()
# -> if driver and not isinstance(driver, string_types):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(51)__init__()
# -> if schema and not hasattr(schema, 'get'):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(53)__init__()
# -> if crs and not isinstance(crs, (dict,) + string_types):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(55)__init__()
# -> if crs_wkt and not isinstance(crs_wkt, string_types):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(57)__init__()
# -> if encoding and not isinstance(encoding, string_types):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(59)__init__()
# -> if layer and not isinstance(layer, tuple(list(string_types) + [int])):
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(61)__init__()
# -> if vsi:
# (Pdb) n
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(64)__init__()
# -> if archive and not isinstance(archive, string_types):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(68)__init__()
# -> if (driver == "GPKG" and
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(74)__init__()
# -> self.session = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(75)__init__()
# -> self.iterator = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(76)__init__()
# -> self._len = 0
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(77)__init__()
# -> self._bounds = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(78)__init__()
# -> self._driver = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(79)__init__()
# -> self._schema = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(80)__init__()
# -> self._crs = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(81)__init__()
# -> self._crs_wkt = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(82)__init__()
# -> self.env = None
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(83)__init__()
# -> self.enabled_drivers = enabled_drivers
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(85)__init__()
# -> self.path = vsi_path(path, vsi, archive)
# (Pdb) s
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(456)vsi_path()
# -> def vsi_path(path, vsi=None, archive=None):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(459)vsi_path()
# -> if vsi:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(465)vsi_path()
# -> result = path
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(466)vsi_path()
# -> return result
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(466)vsi_path()->'./data/nyc_c..._2010.geojson'
# -> return result
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(87)__init__()
# -> if mode == 'w':
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(98)__init__()
# -> if layer in (0, None):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(99)__init__()
# -> self.name = 0
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(103)__init__()
# -> self.mode = mode
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(105)__init__()
# -> if self.mode == 'w':
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(134)__init__()
# -> if driver_count == 0:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(138)__init__()
# -> self.env = GDALEnv()
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(139)__init__()
# -> self.env.__enter__()
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(599)__contains__()
# -> def __contains__(self, key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(600)__contains__()
# -> try:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(601)__contains__()
# -> self[key]
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(720)__getitem__()
# -> def __getitem__(self, key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(721)__getitem__()
# -> try:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(722)__getitem__()
# -> value = self._data[self.encodekey(key)]
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(788)encodekey()
# -> def encodekey(key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(789)encodekey()
# -> return encode(key).upper()
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(782)check_str()
# -> def check_str(value):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(783)check_str()
# -> if not isinstance(value, str):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(785)check_str()
# -> return value
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(785)check_str()->'GDAL_DATA'
# -> return value
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(789)encodekey()->'GDAL_DATA'
# -> return encode(key).upper()
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(726)__getitem__()
# -> return self.decodevalue(value)
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(726)__getitem__()->'C:\\Users\\A...o\\data\\gdal'
# -> return self.decodevalue(value)
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(605)__contains__()
# -> return True
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(605)__contains__()->True
# -> return True
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(599)__contains__()
# -> def __contains__(self, key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(600)__contains__()
# -> try:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(601)__contains__()
# -> self[key]
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(720)__getitem__()
# -> def __getitem__(self, key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(721)__getitem__()
# -> try:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(722)__getitem__()
# -> value = self._data[self.encodekey(key)]
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(788)encodekey()
# -> def encodekey(key):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(789)encodekey()
# -> return encode(key).upper()
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(782)check_str()
# -> def check_str(value):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(783)check_str()
# -> if not isinstance(value, str):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(785)check_str()
# -> return value
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(785)check_str()->'PROJ_LIB'
# -> return value
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(789)encodekey()->'PROJ_LIB'
# -> return encode(key).upper()
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(726)__getitem__()
# -> return self.decodevalue(value)
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\os.py(726)__getitem__()->'C:\\Users\\A...na\\proj_data'
# -> return self.decodevalue(value)
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(605)__contains__()
# -> return True
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\_collections_abc.py(605)__contains__()->True
# -> return True
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(141)__init__()
# -> if self.mode == "r":
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(142)__init__()
# -> self._driver = driver
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(143)__init__()
# -> self.encoding = encoding
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(144)__init__()
# -> self.session = Session()
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\site-packages\fiona\collection.py(145)__init__()
# -> self.session.start(self)
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1257)debug()
# -> def debug(self, msg, *args, **kwargs):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1266)debug()
# -> if self.isEnabledFor(DEBUG):
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1515)isEnabledFor()
# -> def isEnabledFor(self, level):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1519)isEnabledFor()
# -> if self.manager.disable >= level:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1521)isEnabledFor()
# -> return level >= self.getEffectiveLevel()
# (Pdb)
# --Call--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1501)getEffectiveLevel()
# -> def getEffectiveLevel(self):
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1508)getEffectiveLevel()
# -> logger = self
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1509)getEffectiveLevel()
# -> while logger:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1510)getEffectiveLevel()
# -> if logger.level:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1512)getEffectiveLevel()
# -> logger = logger.parent
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1509)getEffectiveLevel()
# -> while logger:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1510)getEffectiveLevel()
# -> if logger.level:
# (Pdb)
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1511)getEffectiveLevel()
# -> return logger.level
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1511)getEffectiveLevel()->30
# -> return logger.level
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1521)isEnabledFor()->False
# -> return level >= self.getEffectiveLevel()
# (Pdb)
# --Return--
# > c:\users\alex\anaconda3\envs\geoplot\lib\logging\__init__.py(1266)debug()->None
# -> if self.isEnabledFor(DEBUG):
# (Pdb)
